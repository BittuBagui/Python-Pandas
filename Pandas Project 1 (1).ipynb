# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Titanic-Dataset (1).csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# on a perticuler column # Age

# %%
df['Age'].isnull().sum()
# Out:
# 177

# %%
# Impute the null value
df['Age'].fillna(df['Age'].mean(), inplace = True)
df['Age'].isnull().sum()
# Out:
# 0

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df['Sex'] = df['Sex'].map({'male' : '0' , 'female' : '1'})

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1      0
# 2                             Heikkinen, Miss. Laina   1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1      0
# 4                           Allen, Mr. William Henry   0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
#find the las name and first name from the name column using # lamda function

# %%
 df['Last Name'] = df['Name'].apply(lambda x: x.split(',')[0])
df['First Name'] = df['Name'].apply(lambda x: ' '.join(x.split(',')[1:]))

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1      0
# 2                             Heikkinen, Miss. Laina   1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1      0
# 4                           Allen, Mr. William Henry   0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  Last Name  \
# 0         A/5 21171   7.2500   NaN        S     Braund
# 1          PC 17599  71.2833   C85        C    Cumings
# 2  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3            113803  53.1000  C123        S   Futrelle
# ...

# %%
df = df.drop(['PassengerId'], axis = 1)

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name Sex  \
# 0         0       3                            Braund, Mr. Owen Harris   0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1
# 2         1       3                             Heikkinen, Miss. Laina   1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1
# 4         0       3                           Allen, Mr. William Henry   0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked  Last Name  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S     Braund
# 1  38.0      1      0          PC 17599  71.2833   C85        C    Cumings
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3  35.0      1      0            113803  53.1000  C123        S   Futrelle
# 4  35.0      0      0            373450   8.0500   NaN        S      Allen
#
#                                     First Name
# ...

# %%
df = df.rename(columns = {'Sex' : 'Gender'})

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name Gender  \
# 0         0       3                            Braund, Mr. Owen Harris      0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1
# 2         1       3                             Heikkinen, Miss. Laina      1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1
# 4         0       3                           Allen, Mr. William Henry      0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked  Last Name  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S     Braund
# 1  38.0      1      0          PC 17599  71.2833   C85        C    Cumings
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3  35.0      1      0            113803  53.1000  C123        S   Futrelle
# 4  35.0      0      0            373450   8.0500   NaN        S      Allen
#
# ...

# %%
 df_trird_class = df[df['Pclass'] == 3]

# %%
df_trird_class.head()
# Out:
#    Survived  Pclass                            Name Gender        Age  SibSp  \
# 0         0       3         Braund, Mr. Owen Harris      0  22.000000      1
# 2         1       3          Heikkinen, Miss. Laina      1  26.000000      0
# 4         0       3        Allen, Mr. William Henry      0  35.000000      0
# 5         0       3                Moran, Mr. James      0  29.699118      0
# 7         0       3  Palsson, Master. Gosta Leonard      0   2.000000      3
#
#    Parch            Ticket     Fare Cabin Embarked  Last Name  \
# 0      0         A/5 21171   7.2500   NaN        S     Braund
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 4      0            373450   8.0500   NaN        S      Allen
# 5      0            330877   8.4583   NaN        Q      Moran
# 7      1            349909  21.0750   NaN        S    Palsson
#
#                First Name
# 0         Mr. Owen Harris
# 2             Miss. Laina
# 4       Mr. William Henry
# ...

# %%
df_trird_class.value_counts().sum()
# Out:
# 12

# %%
df_trird_class.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 491 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Survived    491 non-null    int64
#  1   Pclass      491 non-null    int64
#  2   Name        491 non-null    object
#  3   Gender      491 non-null    object
#  4   Age         491 non-null    float64
#  5   SibSp       491 non-null    int64
#  6   Parch       491 non-null    int64
#  7   Ticket      491 non-null    object
#  8   Fare        491 non-null    float64
#  9   Cabin       12 non-null     object
#  10  Embarked    491 non-null    object
#  11  Last Name   491 non-null    object
#  12  First Name  491 non-null    object
# dtypes: float64(2), int64(4), object(7)
# memory usage: 53.7+ KB

# %%
df_trird_class.count()
# Out:
# Survived      491
# Pclass        491
# Name          491
# Gender        491
# Age           491
# SibSp         491
# Parch         491
# Ticket        491
# Fare          491
# Cabin          12
# Embarked      491
# Last Name     491
# First Name    491
# dtype: int64

# %%
df_trird_class['Survived'].value_counts()
# Out:
# Survived
# 0    372
# 1    119
# Name: count, dtype: int64

# %%
df_aged = df['Age'] > 60

# %%
df_aged.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Age, dtype: bool

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name Gender  \
# 0         0       3                            Braund, Mr. Owen Harris      0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1
# 2         1       3                             Heikkinen, Miss. Laina      1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1
# 4         0       3                           Allen, Mr. William Henry      0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked  Last Name  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S     Braund
# 1  38.0      1      0          PC 17599  71.2833   C85        C    Cumings
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3  35.0      1      0            113803  53.1000  C123        S   Futrelle
# 4  35.0      0      0            373450   8.0500   NaN        S      Allen
#
# ...

# %%
df1 = df [['Age', 'Pclass', 'Gender']]

# %%
df1.head()
# Out:
#     Age  Pclass Gender
# 0  22.0       3      0
# 1  38.0       1      1
# 2  26.0       3      1
# 3  35.0       1      1
# 4  35.0       3      0

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name Gender  \
# 0         0       3                            Braund, Mr. Owen Harris      0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1
# 2         1       3                             Heikkinen, Miss. Laina      1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1
# 4         0       3                           Allen, Mr. William Henry      0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked  Last Name  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S     Braund
# 1  38.0      1      0          PC 17599  71.2833   C85        C    Cumings
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3  35.0      1      0            113803  53.1000  C123        S   Futrelle
# 4  35.0      0      0            373450   8.0500   NaN        S      Allen
#
# ...

# %%
numerical = ['int16','int32','int64','float16','float32','float64']
df_num = df.select_dtypes(include = numerical)

# %%
df_num.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare
# 0         0       3  22.0      1      0   7.2500
# 1         1       1  38.0      1      0  71.2833
# 2         1       3  26.0      0      0   7.9250
# 3         1       1  35.0      1      0  53.1000
# 4         0       3  35.0      0      0   8.0500

# %%
catagorical = ['object']
df_cat = df.select_dtypes(include = catagorical)

# %%
df_cat.head()
# Out:
#                                                 Name Gender            Ticket  \
# 0                            Braund, Mr. Owen Harris      0         A/5 21171
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1          PC 17599
# 2                             Heikkinen, Miss. Laina      1  STON/O2. 3101282
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1            113803
# 4                           Allen, Mr. William Henry      0            373450
#
#   Cabin Embarked  Last Name                                   First Name
# 0   NaN        S     Braund                              Mr. Owen Harris
# 1   C85        C    Cumings   Mrs. John Bradley (Florence Briggs Thayer)
# 2   NaN        S  Heikkinen                                  Miss. Laina
# 3  C123        S   Futrelle           Mrs. Jacques Heath (Lily May Peel)
# 4   NaN        S      Allen                            Mr. William Henry

# %%
## LOC & ILOC

# %%
# First 100 rowa ND ALL COLUMNS

# %%
df = df.iloc[:100, :]

# %%
df
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# ..          ...       ...     ...
# 95           96         0       3
# 96           97         0       1
# 97           98         1       1
# 98           99         1       2
# 99          100         0       2
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# ..                                                ...     ...   ...    ...
# ...

# %%
df_sub2 = df.iloc[:250, [1,8]]

# %%
df_sub2
# Out:
#     Survived            Ticket
# 0          0         A/5 21171
# 1          1          PC 17599
# 2          1  STON/O2. 3101282
# 3          1            113803
# 4          0            373450
# ..       ...               ...
# 95         0            374910
# 96         0          PC 17754
# 97         1          PC 17759
# 98         1            231919
# 99         0            244367
#
# [100 rows x 2 columns]

# %%
df_sub4 = df.loc[(df['Age'] > 50), ['Sex', 'Age']]
df_sub4
# Out:
#        Sex   Age
# 6     male  54.0
# 11  female  58.0
# 15  female  55.0
# 33    male  66.0
# 54    male  65.0
# 94    male  59.0
# 96    male  71.0

# %%
# Append

# %%
row = dict({'Age' : 24, 'Full Name' : 'Peter', 'Survived' : 'Y'})
df = df.append([df, row] , ignore_index = True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9424\16575633.py in ?()
#       1 row = dict({'Age' : 24, 'Full Name' : 'Peter', 'Survived' : 'Y'})
# ----> 2 df = df.append([df, row] , ignore_index = True)
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
## Sorting

# %%
df = df.sort_values(by = ['Age'], ascending = True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 630          631         1       1      Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                       Svensson, Mr. Johan
# 493          494         0       1                   Artagaveytia, Mr. Ramon
# 96            97         0       1                 Goldschmidt, Mr. George B
# 116          117         0       3                      Connors, Mr. Patrick
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
sno = [i+1 for i in range(100)]
marks = np.random.randint(100, size = 100)
print(len(marks))
marks_df = pd.DataFrame({'sno' : sno, 'marks' : marks})
marks_df.head()
# Out:
# 100
#    sno  marks
# 0    1     74
# 1    2      8
# 2    3     69
# 3    4     54
# 4    5     48

# %%
sno = [i+1 for i in range(100)]
Age = np.random.randint(100, size = 100)
print(len(marks))
Age_df = pd.DataFrame({'sno' : sno, 'Age' : Age})
Age_df.head()
# Out:
# 100
#    sno  Age
# 0    1   17
# 1    2   27
# 2    3   77
# 3    4    9
# 4    5   15

# %%
# Cross Join

# %%
cross_join = pd.merge(marks_df, Age_df, how = 'cross')
cross_join
# Out:
#       sno_x  marks  sno_y  Age
# 0         1     74      1   17
# 1         1     74      2   27
# 2         1     74      3   77
# 3         1     74      4    9
# 4         1     74      5   15
# ...     ...    ...    ...  ...
# 9995    100     54     96   11
# 9996    100     54     97   81
# 9997    100     54     98   73
# 9998    100     54     99   32
# 9999    100     54    100   56
#
# [10000 rows x 4 columns]

# %%
inner_join = pd.merge(marks_df, Age_df, how = 'inner')
inner_join
# Out:
#     sno  marks  Age
# 0     1     74   17
# 1     2      8   27
# 2     3     69   77
# 3     4     54    9
# 4     5     48   15
# ..  ...    ...  ...
# 95   96     11   11
# 96   97     38   81
# 97   98     42   73
# 98   99      8   32
# 99  100     54   56
#
# [100 rows x 3 columns]

# %%
left_join = pd.merge(marks_df, Age_df, how = 'left')
left_join
# Out:
#     sno  marks  Age
# 0     1     74   17
# 1     2      8   27
# 2     3     69   77
# 3     4     54    9
# 4     5     48   15
# ..  ...    ...  ...
# 95   96     11   11
# 96   97     38   81
# 97   98     42   73
# 98   99      8   32
# 99  100     54   56
#
# [100 rows x 3 columns]

# %%
right_join = pd.merge(marks_df, Age_df, how = 'right')
right_join
# Out:
#     sno  marks  Age
# 0     1     74   17
# 1     2      8   27
# 2     3     69   77
# 3     4     54    9
# 4     5     48   15
# ..  ...    ...  ...
# 95   96     11   11
# 96   97     38   81
# 97   98     42   73
# 98   99      8   32
# 99  100     54   56
#
# [100 rows x 3 columns]

# %%
outer_join = pd.merge(marks_df, Age_df, how = 'outer')
outer_join
# Out:
#     sno  marks  Age
# 0     1     74   17
# 1     2      8   27
# 2     3     69   77
# 3     4     54    9
# 4     5     48   15
# ..  ...    ...  ...
# 95   96     11   11
# 96   97     38   81
# 97   98     42   73
# 98   99      8   32
# 99  100     54   56
#
# [100 rows x 3 columns]
